# %% [markdown]
# <a href="https://colab.research.google.com/github/nakhwaasim/Practicals/blob/main/1_Basic_Image_Reading_Prac.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from cv2 import *
import matplotlib.pyplot as plt
Img = imread('/content/58146b1.png')
Img_rgb = cvtColor(Img,COLOR_BGR2RGB)
Img_gray = cvtColor(Img,COLOR_BGR2GRAY)
plt.figure()
plt.subplot(221),plt.imshow(Img),plt.title('BGR IMAGE')
plt.axis('off')
plt.subplot(222),plt.imshow(Img_rgb),plt.title('RGB IMAGE')
plt.axis('off')
plt.subplot(223),plt.imshow(Img_gray),plt.title('GRAY IMAGE')
plt.axis('off')
plt.show()
print('helo')
# Out:
# helo
